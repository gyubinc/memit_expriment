# %% [markdown]
# name: memit
# channels:
#   - pytorch
#   - defaults
# dependencies:
#   - python=3.9.7
#   - pip=21.2.4
#   - cudatoolkit=11.3
#   - pytorch==1.12.1
#   - pip:
#     - einops==0.4.0
#     - higher==0.2.1
#     - hydra-core==1.2.0
#     - transformers==4.23.1
#     - datasets==1.18.3
#     - matplotlib==3.6.1
#     - spacy==3.4.1
#     - scipy==1.9.2
#     - scikit-learn==1.0.2
#     - nltk==3.7
#     - jupyter==1.0.0

# %%
# !pip install torch==1.12.1
# !pip install einops==0.4.0
# !pip install higher==0.2.1
# !pip install hydra-core==1.2.0
# !pip install transformers==4.23.1
# !pip install datasets==1.18.3
# !pip install matplotlib==3.6.1
# !pip install spacy==3.4.1
# !pip install scipy==1.9.2
# !pip install scikit-learn==1.0.2
# !pip install nltk==3.7
# !pip install jupyter==1.0.0
# !pip install torchdata==0.4.0
# !pip install portalocker==2.0.0
# !pip install torchtext==0.13.0
# Out:
# Requirement already satisfied: torch==1.12.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (1.12.1)
# Requirement already satisfied: typing-extensions in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from torch==1.12.1) (4.11.0)
# Requirement already satisfied: einops==0.4.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (0.4.0)
# Requirement already satisfied: higher==0.2.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (0.2.1)
# Requirement already satisfied: torch in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from higher==0.2.1) (1.12.1)
# Requirement already satisfied: typing-extensions in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from torch->higher==0.2.1) (4.11.0)
# Requirement already satisfied: hydra-core==1.2.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (1.2.0)
# Requirement already satisfied: omegaconf~=2.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from hydra-core==1.2.0) (2.3.0)
# Requirement already satisfied: packaging in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from hydra-core==1.2.0) (24.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from hydra-core==1.2.0) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from omegaconf~=2.2->hydra-core==1.2.0) (6.0.1)
# Requirement already satisfied: transformers==4.23.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (4.23.1)
# Requirement already satisfied: filelock in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from transformers==4.23.1) (3.13.4)
# Requirement already satisfied: packaging>=20.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from transformers==4.23.1) (24.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from transformers==4.23.1) (2024.4.16)
# Requirement already satisfied: numpy>=1.17 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from transformers==4.23.1) (1.26.4)
# Requirement already satisfied: requests in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from transformers==4.23.1) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from transformers==4.23.1) (6.0.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from transformers==4.23.1) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from transformers==4.23.1) (4.66.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from transformers==4.23.1) (0.22.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.23.1) (4.11.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.23.1) (2024.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests->transformers==4.23.1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests->transformers==4.23.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests->transformers==4.23.1) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests->transformers==4.23.1) (3.7)
# Requirement already satisfied: datasets==1.18.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (1.18.3)
# Requirement already satisfied: xxhash in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (3.4.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (1.26.4)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (15.0.2)
# Requirement already satisfied: tqdm>=4.62.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (4.66.2)
# Requirement already satisfied: pandas in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (2.2.2)
# Requirement already satisfied: dill in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (0.3.8)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (2024.3.1)
# Requirement already satisfied: requests>=2.19.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (2.31.0)
# Requirement already satisfied: aiohttp in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (3.9.5)
# Requirement already satisfied: packaging in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (24.0)
# Requirement already satisfied: multiprocess in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from datasets==1.18.3) (0.70.16)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from aiohttp->datasets==1.18.3) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from aiohttp->datasets==1.18.3) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from aiohttp->datasets==1.18.3) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from aiohttp->datasets==1.18.3) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from aiohttp->datasets==1.18.3) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from aiohttp->datasets==1.18.3) (1.4.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (6.0.1)
# Requirement already satisfied: filelock in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (3.13.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (4.11.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests>=2.19.0->datasets==1.18.3) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests>=2.19.0->datasets==1.18.3) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests>=2.19.0->datasets==1.18.3) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests>=2.19.0->datasets==1.18.3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from pandas->datasets==1.18.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from pandas->datasets==1.18.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from pandas->datasets==1.18.3) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets==1.18.3) (1.16.0)
# Requirement already satisfied: matplotlib==3.6.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from matplotlib==3.6.1) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from matplotlib==3.6.1) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from matplotlib==3.6.1) (3.1.2)
# Requirement already satisfied: numpy>=1.19 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from matplotlib==3.6.1) (1.26.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from matplotlib==3.6.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from matplotlib==3.6.1) (24.0)
# Requirement already satisfied: cycler>=0.10 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from matplotlib==3.6.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from matplotlib==3.6.1) (4.51.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from matplotlib==3.6.1) (10.3.0)
# Requirement already satisfied: six>=1.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib==3.6.1) (1.16.0)
# Requirement already satisfied: spacy==3.4.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (3.4.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (2.4.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (1.0.10)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (3.0.12)
# Requirement already satisfied: pathy>=0.3.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (0.11.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (3.0.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (1.0.5)
# Requirement already satisfied: jinja2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (3.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (2.31.0)
# Requirement already satisfied: setuptools in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (68.2.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (1.9.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (2.0.10)
# Requirement already satisfied: packaging>=20.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (24.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (1.26.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (4.66.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (0.4.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from spacy==3.4.1) (8.1.12)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from pathy>=0.3.5->spacy==3.4.1) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from pathy>=0.3.5->spacy==3.4.1) (0.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy==3.4.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.4.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.4.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.4.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.4.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.4.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.4.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy==3.4.1) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jinja2->spacy==3.4.1) (2.1.5)
# Requirement already satisfied: scipy==1.9.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (1.9.2)
# Collecting numpy<1.26.0,>=1.18.5
#   Using cached numpy-1.25.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.0 requires torch==1.12.0, but you have torch 1.12.1 which is incompatible.
# Successfully installed numpy-1.25.2
# Requirement already satisfied: scikit-learn==1.0.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from scikit-learn==1.0.2) (1.9.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from scikit-learn==1.0.2) (3.4.0)
# Requirement already satisfied: numpy>=1.14.6 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from scikit-learn==1.0.2) (1.25.2)
# Requirement already satisfied: joblib>=0.11 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from scikit-learn==1.0.2) (1.4.0)
# Requirement already satisfied: nltk==3.7 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nltk==3.7) (2024.4.16)
# Requirement already satisfied: click in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nltk==3.7) (8.1.7)
# Requirement already satisfied: tqdm in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nltk==3.7) (4.66.2)
# Requirement already satisfied: joblib in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nltk==3.7) (1.4.0)
# Requirement already satisfied: jupyter==1.0.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: qtconsole in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter==1.0.0) (5.5.1)
# Requirement already satisfied: ipywidgets in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter==1.0.0) (8.1.2)
# Requirement already satisfied: notebook in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter==1.0.0) (7.1.3)
# Requirement already satisfied: nbconvert in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter==1.0.0) (7.16.3)
# Requirement already satisfied: jupyter-console in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter==1.0.0) (6.6.3)
# Requirement already satisfied: ipykernel in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter==1.0.0) (6.29.4)
# Requirement already satisfied: comm>=0.1.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (0.2.2)
# Requirement already satisfied: ipython>=7.23.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (8.6.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (1.6.0)
# Requirement already satisfied: traitlets>=5.4.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (5.14.3)
# Requirement already satisfied: psutil in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (26.0.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (5.7.2)
# Requirement already satisfied: packaging in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (24.0)
# Requirement already satisfied: tornado>=6.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (6.4)
# Requirement already satisfied: debugpy>=1.6.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0) (1.8.1)
# Requirement already satisfied: stack-data in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (2.17.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (3.0.43)
# Requirement already satisfied: typing-extensions in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (4.11.0)
# Requirement already satisfied: decorator in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.19.1)
# Requirement already satisfied: pexpect>4.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (4.9.0)
# Requirement already satisfied: exceptiongroup in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0) (1.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.8.4)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0) (7.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0) (2.9.0.post0)
# Requirement already satisfied: zipp>=0.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0) (3.18.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0) (4.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.7.0)
# Requirement already satisfied: wcwidth in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.2.13)
# Requirement already satisfied: six>=1.5 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0) (1.16.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipywidgets->jupyter==1.0.0) (3.0.10)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from ipywidgets->jupyter==1.0.0) (4.0.10)
# Requirement already satisfied: beautifulsoup4 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (4.12.3)
# Requirement already satisfied: nbclient>=0.5.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (5.10.4)
# Requirement already satisfied: markupsafe>=2.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (2.1.5)
# Requirement already satisfied: jinja2>=3.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (3.1.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (6.1.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (3.0.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (0.3.0)
# Requirement already satisfied: defusedxml in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0) (0.7.1)
# Requirement already satisfied: webencodings in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->jupyter==1.0.0) (0.5.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0) (4.21.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0) (2.19.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (0.18.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (2023.12.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (23.2.0)
# Requirement already satisfied: referencing>=0.28.4 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (0.34.0)
# Requirement already satisfied: soupsieve>1.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0) (2.5)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (4.1.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (2.26.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from notebook->jupyter==1.0.0) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (4.3.0)
# Requirement already satisfied: overrides>=5.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (1.7.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (0.18.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (23.1.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (0.20.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (0.5.3)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (0.10.0)
# Requirement already satisfied: sniffio>=1.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (3.7)
# Requirement already satisfied: argon2-cffi-bindings in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (21.2.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (0.1.4)
# Requirement already satisfied: pyyaml>=5.3 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (6.0.1)
# Requirement already satisfied: uri-template in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (1.3.0)
# Requirement already satisfied: fqdn in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (2.4)
# Requirement already satisfied: webcolors>=1.11 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (1.13)
# Requirement already satisfied: isoduration in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (20.11.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0) (2.2.5)
# Requirement already satisfied: tomli>=1.2.2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0) (2.0.1)
# Requirement already satisfied: httpx>=0.25.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0) (0.27.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0) (2.0.4)
# Requirement already satisfied: httpcore==1.* in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0) (1.0.5)
# Requirement already satisfied: certifi in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0) (2024.2.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0) (0.14.0)
# Requirement already satisfied: json5>=0.9.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0) (0.9.25)
# Requirement already satisfied: babel>=2.10 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0) (2.14.0)
# Requirement already satisfied: requests>=2.31 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0) (3.3.2)
# Requirement already satisfied: cffi>=1.0.1 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (1.16.0)
# Requirement already satisfied: pycparser in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0) (2.9.0.20240316)
# Requirement already satisfied: qtpy>=2.4.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from qtconsole->jupyter==1.0.0) (2.4.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (2.0.1)
# Requirement already satisfied: pure-eval in /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0) (0.2.2)

# %%
# !nvidia-smi
# Out:
# Fri May  3 11:56:53 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 520.61.05    Driver Version: 520.61.05    CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A6000    On   | 00000000:31:00.0 Off |                    0 |
# | 30%   38C    P8    19W / 300W |      3MiB / 46068MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A6000    On   | 00000000:4B:00.0 Off |                    0 |
# | 30%   35C    P8    20W / 300W |      3MiB / 46068MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os

# GPU 1번만 사용하도록 설정
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# 확인을 위해 현재 설정된 환경 변수 출력
print("Configured GPU:", os.environ['CUDA_VISIBLE_DEVICES'])
# Out:
# Configured GPU: 1

# %%
import torch
print("Available GPUs:", torch.cuda.device_count())
# torch.cuda.set_device(1)
print("Current GPU:", torch.cuda.current_device())
# Out:
# Available GPUs: 1
# Current GPU: 0

# %%
import torch
from torch.utils.data import Dataset
# from torchtext.datasets import AG_NEWS
# from torchtext.data.functional import to_map_style_dataset
from transformers import XLNetTokenizer, XLNetForSequenceClassification, Trainer, TrainingArguments
from transformers import DataCollatorWithPadding
import numpy as np
import pandas as pd


# 데이터셋 다운로드
# train_dataset = AG_NEWS(split='train')
# test_dataset = AG_NEWS(split='test')

train_dataset = pd.read_csv('AG_NEWS/train.csv')
test_dataset = pd.read_csv('AG_NEWS/test.csv')


# XLNet tokenizer 및 모델 로드
tokenizer = XLNetTokenizer.from_pretrained('xlnet-base-cased')
model = XLNetForSequenceClassification.from_pretrained('xlnet-base-cased', num_labels=4)

# 데이터 전처리 함수 정의
def data_process(df):
    
    data = [tokenizer(item, truncation=True, padding='max_length', max_length=128) for item in df['Description']]
    labels = torch.tensor([int(item) - 1 for item in df['Class Index']])  # 레이블을 0부터 시작하도록 조정
    return data, labels

# 훈련 데이터와 테스트 데이터를 전처리합니다.
train_data, train_labels = data_process(train_dataset)
test_data, test_labels = data_process(test_dataset)

# 데이터셋 클래스 정의
class AGNewsDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

    def __len__(self):
        return len(self.labels)

# Dataset 객체 생성
train_dataset = AGNewsDataset({k: v for k, v in zip(train_data[0].keys(), zip(*[d.values() for d in train_data]))}, train_labels)
test_dataset = AGNewsDataset({k: v for k, v in zip(test_data[0].keys(), zip(*[d.values() for d in test_data]))}, test_labels)

# TrainingArguments 설정
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=5,
    per_device_train_batch_size=256,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=100,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True
)

# 성능 메트릭 계산 함수
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=1)
    return {'accuracy': (predictions == labels).mean()}

# Trainer 설정
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,  # DataLoader 대신 Dataset 사용
    eval_dataset=test_dataset,    # DataLoader 대신 Dataset 사용
    compute_metrics=compute_metrics,
    data_collator=DataCollatorWithPadding(tokenizer)
)

# 훈련 실행
trainer.train()

# 테스트 데이터에 대한 평가 수행
results = trainer.evaluate()
print(results)
# Out:
# Some weights of the model checkpoint at xlnet-base-cased were not used when initializing XLNetForSequenceClassification: ['lm_loss.bias', 'lm_loss.weight']
# - This IS expected if you are initializing XLNetForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLNetForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['sequence_summary.summary.weight', 'sequence_summary.summary.bias', 'logits_proj.bias', 'logits_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/gyubin/anaconda3/envs/memit_ex/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 120000
#   Num Epochs = 5
#   Instantaneous batch size per device = 256
#   Total train batch size (w. parallel, distributed & accumulation) = 256
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2345
#     <div>
#
#       <progress value='2345' max='2345' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2345/2345 1:22:33, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.227100</td>
#       <td>0.223828</td>
#       <td>0.925132</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.174100</td>
#       <td>0.182310</td>
#       <td>0.937500</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.119700</td>
#       <td>0.183105</td>
#       <td>0.943421</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.081300</td>
#       <td>0.205806</td>
#       <td>0.941842</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.053600</td>
#       <td>0.224922</td>
#       <td>0.939079</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 7600
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-469
# Configuration saved in ./results/checkpoint-469/config.json
# Model weights saved in ./results/checkpoint-469/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 7600
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-938
# Configuration saved in ./results/checkpoint-938/config.json
# Model weights saved in ./results/checkpoint-938/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 7600
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1407
# Configuration saved in ./results/checkpoint-1407/config.json
# Model weights saved in ./results/checkpoint-1407/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 7600
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-1876
# Configuration saved in ./results/checkpoint-1876/config.json
# Model weights saved in ./results/checkpoint-1876/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 7600
#   Batch size = 8
# Saving model checkpoint to ./results/checkpoint-2345
# Configuration saved in ./results/checkpoint-2345/config.json
# Model weights saved in ./results/checkpoint-2345/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./results/checkpoint-938 (score: 0.18231040239334106).
# ***** Running Evaluation *****
#   Num examples = 7600
#   Batch size = 8
#     <div>
#
#       <progress value='950' max='950' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [950/950 00:22]
#     </div>
# {'eval_loss': 0.18231040239334106, 'eval_accuracy': 0.9375, 'eval_runtime': 22.7431, 'eval_samples_per_second': 334.167, 'eval_steps_per_second': 41.771, 'epoch': 5.0}
